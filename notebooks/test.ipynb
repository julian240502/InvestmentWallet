# %%
import yfinance as yf
import pandas as pd
import numpy as np

msft = yf.Ticker("MSFT")
print(msft.info)
# Out:
# {'address1': 'One Microsoft Way', 'city': 'Redmond', 'state': 'WA', 'zip': '98052-6399', 'country': 'United States', 'phone': '425 882 8080', 'website': 'https://www.microsoft.com', 'industry': 'Software - Infrastructure', 'industryKey': 'software-infrastructure', 'industryDisp': 'Software - Infrastructure', 'sector': 'Technology', 'sectorKey': 'technology', 'sectorDisp': 'Technology', 'longBusinessSummary': 'Microsoft Corporation develops and supports software, services, devices and solutions worldwide. The Productivity and Business Processes segment offers office, exchange, SharePoint, Microsoft Teams, office 365 Security and Compliance, Microsoft viva, and Microsoft 365 copilot; and office consumer services, such as Microsoft 365 consumer subscriptions, Office licensed on-premises, and other office services. This segment also provides LinkedIn; and dynamics business solutions, including Dynamics 365, a set of intelligent, cloud-based applications across ERP, CRM, power apps, and p
# ...

# %%
apple= yf.Ticker("aapl")
SP500 = yf.Ticker("CW8.PA")
cac40= yf.Ticker("^FCHI")
BTC = yf.Ticker("BTC-EUR")
MSCI_WORLD = yf.Ticker("AMUN.L")

# show actions (dividends, splits)
apple.actions

# show dividends
apple.dividends

# show splits
apple.splits
# Out:
# Date
# 1987-06-16 00:00:00-04:00    2.0
# 2000-06-21 00:00:00-04:00    2.0
# 2005-02-28 00:00:00-05:00    2.0
# 2014-06-09 00:00:00-04:00    7.0
# 2020-08-31 00:00:00-04:00    4.0
# Name: Stock Splits, dtype: float64

# %%
# Charger les etfs
nasdaq_100 = yf.Ticker("ANX.PA")
eurostoxx_50 = yf.Ticker("E50.PA")
sp500 = yf.Ticker("ES5.PA")

# Charger les actions
dassault_systemes =yf.Ticker("DSY.PA")
microsoft = yf.Ticker("MSFT")
nvidia = yf.Ticker("NVDA")

# Charger les cryptos
BTC = yf.Ticker("BTC-EUR")
SOL = yf.Ticker("SOL-EUR")
XRP = yf.Ticker("XRP-EUR")
ETH = yf.Ticker("ETH-EUR")


etfs = [nasdaq_100, eurostoxx_50, sp500]
cryptos = [BTC, SOL, XRP, ETH]
actions = [microsoft, dassault_systemes, nvidia]

# %%
import yfinance as yf

# Définir les symboles par catégorie
etf_symbols = ["ANX.PA", "E50.PA", "ES5.PA"]
action_symbols = ["MSFT", "DSY.PA", "NVDA"]
crypto_symbols = ["BTC-EUR", "SOL-EUR", "XRP-EUR", "ETH-EUR"]

# Définir la période souhaitée
start_date = "2020-01-01"
end_date = "2025-01-01"

# Télécharger les données pour chaque catégorie
data_etfs = yf.download(etf_symbols, start=start_date, end=end_date, group_by='ticker')
data_actions = yf.download(action_symbols, start=start_date, end=end_date, group_by='ticker')
data_cryptos = yf.download(crypto_symbols, start=start_date, end=end_date, group_by='ticker')

# Vous pouvez ensuite sauvegarder les résultats pour un accès ultérieur :
data_etfs.to_csv("../data/raw/etfs.csv")
data_actions.to_csv("../data/raw/actions.csv")
data_cryptos.to_csv("../data/raw/cryptos.csv")
# Out:
# YF.download() has changed argument auto_adjust default to True
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ES5.PA?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ES5.PA&crumb=Yd%2FmQECdqOz
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/E50.PA?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=E50.PA&crumb=Yd%2FmQECdqOz
# [*********************100%***********************]  1 of 3 completed
#
# 2 Failed downloads:
# ['ES5.PA', 'E50.PA']: AttributeError("'NoneType' object has no attribute 'update'")
# [*********************100%***********************]  3 of 3 completed4 of 3 completed
# [*********************100%***********************]  4 of 4 completed

# %%
data_etfs['ANX.PA']['High'].plot(title='ANX.PA')
# Out:
# <Axes: title={'center': 'ANX.PA'}, xlabel='Date'>

# %%
data_actions['DSY.PA']['High'].plot(title='DASSAULT SYSTEMES',ylabel='Prix')
# Out:
# <Axes: title={'center': 'DASSAULT SYSTEMES'}, xlabel='Date', ylabel='Prix'>

# %%
data_etfs_process=data_etfs.dropna(inplace=True)
data_etfs_process

# %%
import sys
import os
# Ajouter le chemin du répertoire parent au sys.path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))


from src.preprocessing import clean_data , process_category

process_category('cryptos')
# Out:
# Traitement terminé pour cryptos. Données sauvegardées dans c:\Users\akues\OneDrive\Documents\GitHub\InvestmentWallet\src\..\data\processed\cryptos_processed.csv
# c:\Users\akues\OneDrive\Documents\GitHub\InvestmentWallet\src\preprocessing.py:13: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill').fillna(method='bfill')

# %%
import sys
import os
# Ajouter le chemin du répertoire parent au sys.path

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

from src.preprocessing import clean_data , process_category

process_category('cryptos')
process_category('etfs')
process_category('actions')
# Out:
# Traitement terminé pour cryptos. Données sauvegardées dans c:\Users\akues\OneDrive\Documents\GitHub\InvestmentWallet\src\..\data\processed\cryptos_processed.csv
# Traitement terminé pour etfs. Données sauvegardées dans c:\Users\akues\OneDrive\Documents\GitHub\InvestmentWallet\src\..\data\processed\etfs_processed.csv
# Traitement terminé pour actions. Données sauvegardées dans c:\Users\akues\OneDrive\Documents\GitHub\InvestmentWallet\src\..\data\processed\actions_processed.csv
# c:\Users\akues\OneDrive\Documents\GitHub\InvestmentWallet\src\preprocessing.py:13: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill').fillna(method='bfill')
# c:\Users\akues\OneDrive\Documents\GitHub\InvestmentWallet\src\preprocessing.py:13: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# ...
