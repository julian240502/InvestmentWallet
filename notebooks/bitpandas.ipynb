# %%
import os
from dotenv import load_dotenv

# Charger le contenu du fichier .env dans l'environnement
load_dotenv()

# Récupérer la clé API bitpandas depuis la variable d'environnement
BITPANDAS_API_KEY = os.getenv('BITPANDAS_API_KEY')

# %%
print(BITPANDAS_API_KEY)
# Out:
# d9694973b91dc1b08790b0246a44f2fb6feee31e78b9c0d26701fdd77a6475fd82be2fb0c384dd7fb4b02a914ba7bb70875050bee321c7b87ab06fd70cd8989f

# %%
import requests

# Exemple d'URL pour récupérer le ticker (vérifiez l'URL exacte dans la documentation)
url = "https://api.bitpanda.com/v1/ticker"

# Envoyer la requête GET sans authentification (pour l’API publique)
response = requests.get(url)

if response.ok:
    data = response.json()
    print("Données du ticker :", data)
else:
    print("Erreur lors de la récupération des données :", response.status_code)
# Out:
# Données du ticker : {'XAU': {'EUR': '91.62', 'USD': '104.07', 'CHF': '84.87', 'GBP': '79.57', 'TRY': '3947.27', 'PLN': '392.99', 'HUF': '37535.02', 'CZK': '2301.83', 'SEK': '1017.14', 'DKK': '684.43'}, 'BTC': {'EUR': '75000.04', 'USD': '85191.61', 'CHF': '69471.38', 'GBP': '65130.75', 'TRY': '3231149.13', 'PLN': '321695.02', 'HUF': '30725382.56', 'CZK': '1884225.81', 'SEK': '832613.43', 'DKK': '560262.55'}, 'ETH': {'EUR': '1450.52', 'USD': '1647.63', 'CHF': '1343.60', 'GBP': '1259.65', 'TRY': '62491.45', 'PLN': '6221.68', 'HUF': '594238.65', 'CZK': '36441.52', 'SEK': '16103.01', 'DKK': '10835.66'}, 'USDT': {'EUR': '0.8820', 'USD': '1.0019', 'CHF': '0.8170', 'GBP': '0.7660', 'TRY': '37.9996', 'PLN': '3.7833', 'HUF': '361.3431', 'CZK': '22.1593', 'SEK': '9.7919', 'DKK': '6.5889'}, 'XRP': {'EUR': '1.9260', 'USD': '2.1877', 'CHF': '1.7840', 'GBP': '1.6725', 'TRY': '82.9754', 'PLN': '8.2611', 'HUF': '789.0225', 'CZK': '48.3866', 'SEK': '21.3814', 'DKK': '14.3874'}, 'BNB': {'EUR': '519.98', 'USD': '590.64', 'CHF': '481.65', 'GBP': '451.56', 'TRY': '22401.77', 'PLN': '2230.33', 'HUF': '213021.06', 'CZK': '13063.46', 'SEK': '5772.56', 'DKK': '3884.34'}, 'XAG': {'EUR': '0.9138', 'USD': '1.0379', 'CHF': '0.8464', 'GBP': '0.7935', 'TRY': '39.3674', 'PLN': '3.9194', 'HUF': '374.3489', 'CZK': '22.9568', 'SEK': '10.1443', 'DKK': '6.8261'}, 'SOL': {'EUR': '116.53', 'USD': '132.36', 'CHF': '107.94', 'GBP': '101.19', 'TRY': '5020.13', 'PLN': '499.81', 'HUF': '47737.05', 'CZK': '2
00446542', 'CZK': '0.00027384', 'SEK': '0.00012101', 'DKK': '0.00008142'}, 'BCH': {'EUR': '307.64', 'USD': '349.45', 'CHF': '284.96', 'GBP': '267.16', 'TRY': '13253.80', 'PLN': '1319.56', 'HUF': '126031.98', 'CZK': '7728.88', 'SEK': '3415.28', 'DKK': '2298.13'}, 'OM': {'EUR': '5.0706', 'USD': '5.7596', 'CHF': '4.6968', 'GBP': '4.4034', 'TRY': '218.4517', 'PLN': '21.7492', 'HUF': '2077.2830', 'CZK': '127.3888', 'SEK': '56.2914', 'DKK': '37.8783'}, 'LTC': {'EUR': '70. ...

# %%
import os
import requests

url = "https://api.bitpanda.com/v1/trades"

headers = {
    'X-Api-Key': BITPANDAS_API_KEY  
}

response = requests.get(url, headers=headers)

if response.ok:
    account_data = response.json()
    print("Données du compte :", account_data)
else:
    print("Erreur :", response.status_code)
# Out:
# Données du compte : {'data': [{'type': 'trade', 'attributes': {'status': 'finished', 'type': 'buy', 'cryptocoin_id': '1', 'cryptocoin_symbol': 'BTC', 'fiat_id': '1', 'amount_fiat': '100.00', 'amount_cryptocoin': '0.00134018', 'fiat_to_eur_rate': '1.00000000', 'wallet_id': '58353f8f-3e02-43b1-ba1f-33f87d336280', 'fiat_wallet_id': '1eeded08-57d8-6226-b92b-b9adede5770c', 'time': {'date_iso8601': '2025-04-06T19:55:26+02:00', 'unix': '1743962126'}, 'price': '74616.72', 'is_swap': False, 'is_savings': False, 'tags': [], 'bfc_used': False, 'is_card': False, 'fee': {'type': 'fee', 'attributes': {'fee_percentage': None, 'fee_amount_in_fiat': '1.00000000'}}, 'is_fee_transparent': True}, 'id': '1f0111f9-dfc4-6760-bee1-bc991ae6b9b7'}, {'type': 'trade', 'attributes': {'status': 'finished', 'type': 'buy', 'cryptocoin_id': '3395', 'cryptocoin_symbol': 'RFRM', 'fiat_id': '1', 'amount_fiat': '40.00', 'amount_cryptocoin': '287.93691187', 'fiat_to_eur_rate': '1.00000000', 'wallet_id': '93ee4f20-c647-4238-89d6-639592c7a908', 'fiat_wallet_id': '1eeded08-57d8-6226-b92b-b9adede5770c', 'time': {'date_iso8601': '2025-02-27T14:02:13+01:00', 'unix': '1740661333'}, 'price': '0.1389', 'is_swap': False, 'is_savings': False, 'tags': [], 'bfc_used': False, 'is_card': False, 'fee': {'type': 'fee', 'attributes': {'fee_percentage': None, 'fee_amount_in_fiat': '1.60000000'}}, 'is_fee_transparent': True}, 'id': '1eff50b0-dda7-6240-bcf6-fdb0460242ea'}, {'type': 'trade', 'attributes': {'status': 'finished', 'type': 'buy', 'cryptocoin_id': '33', 'cryptocoin_symbol': 'BEST', 'fiat_id': '1', 'amount_fiat': '0.11', 'amount_cryptocoin': '0.16917062', 'fiat_to_eur_rate': '1.00000000', 'wallet_id': '1eee14ac-e615-6bbc-9d40-c145640d7a5b', 'fiat_wallet_id': '1eeded08-57d8-6226-b92b-b9adede5770c', 'time': {'date_iso8601': '2025-02-27T13:53:42+01:00', 'unix': '1740660822'}, 'price': '0.6502', 'is_swap': True, 'is_savings': False, 'related_swap_trade': {'type': 'trade', 'attributes': {'status': 'finished', 'type': 'sell', 'cryptocoin_id': '30', 'cryptocoin_symbol': 'USDC', 'fiat_id': '1', 'amount_fiat': '0.11', 'amount_cryptocoin': '0.12225605', 'fiat_to_eur_rate': '1.00000000', 'wallet_id': '1efdfcb2-69c3-6a66-a239-d1a75af1a438', 'fiat_wallet_id': '1eeded08-57d8-6226-b92b-b9adede5770c', 'time': {'date_iso8601': '2025-02-27T13:53:42+01:00', 'unix': '1740660822'}, 'price': '0.9543', 'is_swap': True, 'is_savings': False, 'related_swap_trade_id': '1eff509d-873c-6196-bb4d-9571426b158c', 'tags': [], 'bfc_used': False, 'is_card': False, 'fee': {'type': 'fee', 'attributes': {'fee_percentage': None, 'fee_amount_in_fiat': '0.00000000'}}, 'is_fee_transparent': True}, 'id': '1eff509d-8687-66f4-bb4d-9571426b158c'}, 'tags': [], 'bfc_used': False, 'is_card': False, 'fee': {'type': 'fee', 'attributes': {'fee_percentage': None, 'fee_amount_in_fiat': '0.00000000'}}, 'is_fee_transparent': True}, 'id': '1eff509d-873c-6196-bb4d-9571426b158c'}, {'type': 'trade', 'attributes': {'status': 'finished', 'type': 'sell', 'cryptocoin_id': '30', 'cryptocoin_symbol': 'USDC', 'fiat_id': '1', 'amount_fiat': '0.11', 'amount_cryptocoin': '0.12225605', 'fiat_to_eur_rate': '1.00000000', 'wallet_id': '1efdfcb2-69c3-6a66-a239-d1a75af1a438', 'fiat_wallet_id': '1eeded08-57d8-6226-b92b-b9adede5770c', 'time': {'date_iso8601': '2025-02-27T13:53:42+01:00', 'unix': '1740660822'}, 'price': '0.9543', 'is_swap': True, 'is_savings': False, 'related_swap_trade': {'type': 'trade', 'attributes': {'status': 'finished', 'type': 'buy', 'cryptocoin_id': '33', 'cryptocoin_symbol': 'BEST', 'fiat_id': '1', 'amount_fiat': '0.11', 'amount_cryptocoin': '0.16917062', 'fiat_to_eur_rate': '1.00000000', 'wallet_id': '1eee14ac-e615-6bbc-9d40-c145640d7a5b', 'fiat_wallet_id': '1eeded08-57d8-6226-b92b-b9adede5770c', 'time': {'date_iso8601': '2025-02-27T13:53:42+01:00', 'unix': '1740660822'}, 'price': '0.6502', 'is_swap': True, 'is_savings': False, 'related_swap_trade_id': '1eff509d-8687-66f4-bb4d-9571426b158c', 'tags': [], 'bfc_used': False, 'is_ ...
